# %% [markdown]
# <a href="https://colab.research.google.com/github/Bautistacpe/CPE009A/blob/main/Acitvity%231%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assigning variables of different data types in Python

# %%
value = 5
print(value)
# Out:
# 5

# %%
type(value)
# Out:
# int

# %%
value = 5.0
print(value)
# Out:
# 5.0

# %%
#a.
value = 2+3j
print(value)
# Out:
# (2+3j)

# %%
#b.
value = 'Hello World'
print(value)
# Out:
# Hello World

# %%
#c.
value = "Hello World"
print(value)
# Out:
# Hello World

# %%
#d.
value = True
print(value)
# Out:
# True

# %%
#e.
value = False
print(value)
# Out:
# False

# %%
#f.
value = [1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
#g.
value = (1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
#h.
value = {'name': 'Troy Jerron Bautista'}
print(value)
# Out:
# {'name': 'Troy Jerron Bautista'}

# %%
#i.
value = None
print(value)
# Out:
# None

# %%
value = 5
value2 = -6

# %% [markdown]
# Performing Operations with Python

# %%
(value+value2)
# Out:
# -1

# %%
#a.
value, value2 = 5.0, 6
(value+value2)
# Out:
# 11.0

# %%
value, value2 = 5.0, 6
(value-value2)
# Out:
# -1.0

# %%
#b.
value, value2 = -5, 6.1
(value+value2)
# Out:
# 1.0999999999999996

# %%
value, value2 = -5, 6.1
(value-value2)
# Out:
# -11.1

# %%
#c.
value, value2 = "Hello ", 'world'
(value+value2)

#Subtraction allowed because data type is 'string'
# Out:
# 'Hello world'

# %%
#d.
value, value2 = [1,2,3], [4,5,6]
(value+value2)

#Subtraction allowed because variables are arrays
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#e.
value, value2 = (1,2,3), (4,5,6)
(value+value2)

#Subtraction allowed because variables are arrays
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#f.
value, value2 = {"name":"Royce"},{"age":"2"}
(value, value2)

#Subtraction allowed because data type is "dict'
# Out:
# ({'name': 'Royce'}, {'age': '2'})

# %%
value, value2 = 30, 4.

# %%
#a.
print(value*value2)
# Out:
# 120.0

# %%
#b.
print(value2**2)
# Out:
# 16.0

# %%
#c.
print(value2**3)
# Out:
# 64.0

# %%
#d.
print(value*value2+value2**2+1)
# Out:
# 137.0

# %%
#e.
print(value/value2)
# Out:
# 7.5

# %%
#f.
print(value%value2)
# Out:
# 2.0

# %% [markdown]
# Receiving Input Data using Python

# %%
input("Message Name: ")
# Out:
# Message Name: This is a message
# 'This is a message'

# %%
name = input("Enter your name: ")
# Out:
# Enter your name: Troy Jerron Bautista

# %% [markdown]
# Assigning Input Data to a Variable

# %%
name = input("Enter your name: ")
weight = float(input("Enter your weight(kg): "))
height = float(input("Enter your height(m): "))
BMI = (weight/height**2)
print(BMI)
# Out:
# Enter your name: John Ray
# Enter your weight(kg): 60
# Enter your height(m): 1.6764
# 21.349904958763087

# %%
print("Value: "+str(12))
# Out:
# Value: 12

# %%
print("Value: ", 12)
# Out:
# Value:  12

# %% [markdown]
# Supplementary Activity

# %%
#1.
base, height, area = 0,0,0
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))
area = (1/2*base*height)
print("The area of the triangle is: " + str(area))
# Out:
# Enter the base of the triangle: 2.1
# Enter the height of the triangle: 6.7
# The area of the triangle is: 7.035

# %%
#2.
Fahrenheit, Celsius = 0,0
Celsius = float(input("Enter the temperature in Celsius: "))
Fahrenheit = (Celsius*9/5)+32
print("The temperature in Celsius is: " + str(Fahrenheit))
# Out:
# Enter the temperature in Celsius: 22
# The temperature in Celsius is: 71.6

# %%
#3.
Distance, x1, x2, y1, y2 = 0,0,0,0,0
x1 = (float(input("Enter the x1 coordinate: ")))
x2 = (float(input("Enter the x2 coordinate: ")))
y1 = (float(input("Enter the y1 coordinate: ")))
y2 = (float(input("Enter the y2 coordinate: ")))
Distance = ((x2-x1)**2 + (y2-y1)**2)**0.5
print("The distance between the two points is: " + str(Distance))
# Out:
# Enter the x1 coordinate: 2
# Enter the x2 coordinate: 7
# Enter the y1 coordinate: 6
# Enter the y2 coordinate: 3
# The distance between the two points is: 5.830951894845301
