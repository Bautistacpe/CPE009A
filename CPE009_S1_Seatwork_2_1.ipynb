# %% [markdown]
# <a href="https://colab.research.google.com/github/Bautistacpe/CPE009A/blob/main/CPE009_S1_Seatwork_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We want to create a python code for a grading scheme

# Create a function to accept a number of activities
# Compute for the score vs total
# Return the average grade of the student in %
def termCrit(actNumber):
  rawScore = []
  totalScore = []

  for i in range(0, actNumber):
    inputScore = float(input("Score: "))
    inputTotal = float(input("Total: "))

    if inputScore > inputTotal:
      print("\nInvalid Scores.\n")
      inputScore, inputTotal = 0,0
      break
    else:
      rawScore.append(inputScore)
      totalScore.append(inputTotal)

  grade = sum(rawScore) / sum(totalScore)
  grade = grade * 100
  return grade

# %%
# Create a function for the class standing per term
def termCS():
  print(" ")
  print("Hands-on Activities: ")
  termHOA = termCrit(int(input("How many hands-on activities this term?")))

  print(" ")
  print("Quizzes:")
  termQuiz = termCrit(int(input("How many quizzes this term?")))

  print(" ")
  print("Assignment: ")
  termAss = termCrit(int(input("How many assignments?")))

  grade = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  return grade

# %%
# Create a function to compute the term grade
def termGrade():
  print("Computing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))
  print(" ")
  examGrade = (examRaw/examTotal) * 100

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  return grade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print(" ")
  print("Prelim Grade")
  prelimGrade = termGrade()
  print("Prelim Grade: ", prelimGrade)

  print(" ")
  print("Midterm Grade")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade
  print("Midterm Grade: ", finalMG)

  print(" ")
  print("Final Grade")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade
  print("Final Grade: ", finalFG)

  print(" ")

  return finalFG

# %%
def convertGrade(finalFG):
  if finalFG >= 99.0: return 1.00
  elif 96.0 < finalFG < 99.0: return 1.25
  elif 93.0 < finalFG < 96.0: return 1.50
  elif 90.0 < finalFG < 93.0: return 1.75
  elif 87.0 < finalFG < 90.0: return 2.00
  elif 84.0 < finalFG < 87.0: return 2.25
  elif 81.0 < finalFG < 84.0: return 2.50
  elif 78.0 < finalFG < 81.0: return 2.75
  elif 75.0 < finalFG < 78.0: return 3.00
  else: return 5.00
  #The class should add everything else

# %%
# Driver Code

# Trial 1
print("T.I.P. Grade: ", (convertGrade(semesterGrade())))

# Trial 2

# Trial 3
# Out:
#
# Prelim Grade
# Computing for the term grade.
# Exam Score: 80
# Exam Total: 100
#
#
# Hands-on Activities:
# How many hands-on activities this term?3
# Score: 85
# Total: 100
# Score: 95
# Total: 100
# Score: 45
# Total: 50
#
# Quizzes:
# How many quizzes this term?2
# Score: 40
# Total: 50
# Score: 37
# Total: 50
#
# Assignment:
# How many assignments?3
# Score: 25
# Total: 30
# Score: 20
# Total: 30
# Score: 30
# Total: 40
# Prelim Grade:  81.55
#
# Midterm Grade
# Computing for the term grade.
# Exam Score: 75
# Exam Total: 100
#
#
# Hands-on Activities:
# How many hands-on activities this term?3
# Score: 65
# Total: 100
# Score: 80
# Total: 100
# Score: 89
# Total: 100
#
# Quizzes:
# How many quizzes this term?2
# Score: 40
# Total: 50
# Score: 45
# Total: 60
#
# Assignment:
# How many assignments?1
# Score: 38
# Total: 40
# Midterm Grade:  79.2439393939394
#
# Final Grade
# Computing for the term grade.
# Exam Score: 95
# Exam Total: 100
#
#
# Hands-on Activities:
# How many hands-on activities this term?2
# Score: 67
# Total: 80
# Score: 69
# Total: 80
#
# Quizzes:
# How many quizzes this term?1
# Score: 47
# Total: 60
#
# Assignment:
# How many assignments?1
# Score: 30
# Total: 30
# Final Grade:  86.7479797979798
#
# T.I.P. Grade:  2.25

# %% [markdown]
# **What is the difference from the code you created?**
#
# There are four things I changed in the code that changed the output of the code. The first one is printing the term grade in the semester grade, because the output of this code did not display the grade output for all the terms and renders the function useless. Second is changing last function to convert the grade from the finalGrade to finalFG since the finalGrade is not the full computed grade of the final grade, while finalFG is the final computed grade of the semester. Lastly, creating spaces to make the output of the code, only a minor change, as well as putting T.I.P. Grade to know what grading system it is.
