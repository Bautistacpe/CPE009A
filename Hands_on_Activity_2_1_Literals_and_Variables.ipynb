# %% [markdown]
# <a href="https://colab.research.google.com/github/Bautistacpe/CPE009A/blob/main/Copy_of_Hands_on_Activity_2_1_Literals_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title: 2.1 Literals and Variables</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed:** 1/15/2026 |
# | **Section**: CPE12S2 | **Date Submitted:** 1/22/2026 |
# | **Student Name**: 2515417 | **Instructor's Name:** Engr. Maria Rizette Sayo |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# 1.   Discuss the use of variables, constants and literals in a python program.
#
# **Procedure:**
#
# A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:
#
#  1. PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
#  2. PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#  3. MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
#  4. MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#  5. FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
#  6. FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#  7. HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
#  8. Major exams are inputted out of 100%.
#  9. Show the codes that successfully run the program.
#  10. Provide comments or documentation strings for your program.

# %%
#PRELIM CLASS STANDING
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)

#INPUT PRELIM EXAM GRADE
PEX = float(input("Enter Prelim Exam grade: "))
#PRELIM GRADE
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)


#MIDTERM CLASS STANDING
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)

#INPUT MIDTERM EXAM GRADE
MEX = float(input("Enter Midterm Exam grade: "))
#MIDTERM GRADE
MG = (PG*0.33) + (((MEX*0.5) + (MCS*0.5))*0.67)
print("Midterm Grade is: ", "%.2f" % MG)


#FINAL CLASS STANDING
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final CS is: ", FCS)

#INPUT FINAL EXAM GRADE
FEX = float(input("Enter Final Exam grade: "))
#FINAL GRADE
FG = (MG*0.33) + (((FEX*0.5) + (FCS*0.5))*0.67)
print("Final Grade is: ", "%.2f" % FG)
# Out:
# Enter Hands-on Activity grade: 90
# Enter Prelim Quiz grade: 90
# Enter Prelim Assignment grade: 80
# Prelim CS is:  88.0
# Enter Prelim Exam grade: 75
# Prelim Grade is:  81.50
# Enter Hands-on Activity grade: 80
# Enter Midterm Quiz grade: 75
# Enter Midterm Assignment grade: 70
# Midterm CS is:  76.5
# Enter Midterm Exam grade: 80
# Midterm Grade is:  79.32
# Enter Hands-on Activity grade: 90
# Enter Final Quiz grade: 90
# Enter Final Assignment grade: 90
# Final CS is:  90.0
# Enter Final Exam grade: 75
# Final Grade is:  81.45

# %% [markdown]
# **Supplementary Activity**:
#
#   1.  Test 3 students from the program you created.
#   2.  The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
#   3.  Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.

# %%
print("Student 1")
Name = str(input("Enter Student Name: " ))

#PRELIM CLASS STANDING
print(" ")
print("Prelim")
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)

#INPUT PRELIM EXAM GRADE
print(" ")
PEX = float(input("Enter Prelim Exam grade: "))
#PRELIM GRADE
PG = PEX*.5 + PCS*.5


#MIDTERM CLASS STANDING
print(" ")
print("Midterm")
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)

#INPUT MIDTERM EXAM GRADE
print(" ")
MEX = float(input("Enter Midterm Exam grade: "))
#MIDTERM GRADE
MG = (PG*0.33) + (((MEX*0.5) + (MCS*0.5))*0.67)


#FINAL CLASS STANDING
print(" ")
print("Final")
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final CS is: ", FCS)

#INPUT FINAL EXAM GRADE
print(" ")
FEX = float(input("Enter Final Exam grade: "))
#FINAL GRADE
FG = (MG*0.33) + (((FEX*0.5) + (FCS*0.5))*0.67)

#COMPILE NAME OF STUDENT ALONG WITH GRADES FROM PRELIM, MIDTERM, AND FINALS
print(" ")
print("Student Name: ", str(Name))
print("Prelim Grade is: ", "%.2f" % PG)
print("Midterm Grade is: ", "%.2f" % MG)
print("Final Grade is: ", "%.2f" % FG)
print(" ")

#CONVERT FINAL GRADE TO TIP GRADE (ADD REMARKS IF YOU WANT)
if 100 >= FG >= 99:
  print("TIP Grade: 1.00")
  print("Remarks: Excellent")
elif 99 > FG >= 96:
  print("TIP Grade: 1.25")
  print("Remarks: Superior")
elif 96 > FG >= 93:
  print("TIP Grade: 1.50")
  print("Remarks: Meritorious")
elif 93 > FG >= 90:
  print("TIP Grade: 1.75")
  print("Remarks: Very Good")
elif 90 > FG >= 87:
  print("TIP Grade: 2.00")
  print("Remarks: Good")
elif 87 > FG >= 84:
  print("TIP Grade: 2.25")
  print("Remarks: Very Satisfactory")
elif 84 > FG >= 81:
  print("TIP Grade: 2.50")
  print("Remarks: Satisfactory")
elif 81 > FG >= 78:
  print("TIP Grade: 2.75")
  print("Remarks: Fair")
elif 78 > FG >= 75:
  print("TIP Grade: 3.00")
  print("Remarks: Passing")
else:
  print("TIP Grade: 5.00")
  print("Remarks: Failed")
print(" ")

print("Student 2")
Name = str(input("Enter Student Name: " ))

#PRELIM CLASS STANDING
print(" ")
print("Prelim")
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)

#INPUT PRELIM EXAM GRADE
print(" ")
PEX = float(input("Enter Prelim Exam grade: "))
#PRELIM GRADE
PG = PEX*.5 + PCS*.5


#MIDTERM CLASS STANDING
print(" ")
print("Midterm")
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)

#INPUT MIDTERM EXAM GRADE
print(" ")
MEX = float(input("Enter Midterm Exam grade: "))
#MIDTERM GRADE
MG = (PG*0.33) + (((MEX*0.5) + (MCS*0.5))*0.67)


#FINAL CLASS STANDING
print(" ")
print("Final")
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final CS is: ", FCS)

#INPUT FINAL EXAM GRADE
print(" ")
FEX = float(input("Enter Final Exam grade: "))
#FINAL GRADE
FG = (MG*0.33) + (((FEX*0.5) + (FCS*0.5))*0.67)

#COMPILE NAME OF STUDENT ALONG WITH GRADES FROM PRELIM, MIDTERM, AND FINALS
print(" ")
print("Student Name: ", str(Name))
print("Prelim Grade is: ", "%.2f" % PG)
print("Midterm Grade is: ", "%.2f" % MG)
print("Final Grade is: ", "%.2f" % FG)
print(" ")

#CONVERT FINAL GRADE TO TIP GRADE (ADD REMARKS IF YOU WANT)
if 100 >= FG >= 99:
  print("TIP Grade: 1.00")
  print("Remarks: Excellent")
elif 99 > FG >= 96:
  print("TIP Grade: 1.25")
  print("Remarks: Superior")
elif 96 > FG >= 93:
  print("TIP Grade: 1.50")
  print("Remarks: Meritorious")
elif 93 > FG >= 90:
  print("TIP Grade: 1.75")
  print("Remarks: Very Good")
elif 90 > FG >= 87:
  print("TIP Grade: 2.00")
  print("Remarks: Good")
elif 87 > FG >= 84:
  print("TIP Grade: 2.25")
  print("Remarks: Very Satisfactory")
elif 84 > FG >= 81:
  print("TIP Grade: 2.50")
  print("Remarks: Satisfactory")
elif 81 > FG >= 78:
  print("TIP Grade: 2.75")
  print("Remarks: Fair")
elif 78 > FG >= 75:
  print("TIP Grade: 3.00")
  print("Remarks: Passing")
else:
  print("TIP Grade: 5.00")
  print("Remarks: Failed")
print(" ")

print("Student 3")
Name = str(input("Enter Student Name: " ))

#PRELIM CLASS STANDING
print(" ")
print("Prelim")
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)

#INPUT PRELIM EXAM GRADE
print(" ")
PEX = float(input("Enter Prelim Exam grade: "))
#PRELIM GRADE
PG = PEX*.5 + PCS*.5


#MIDTERM CLASS STANDING
print(" ")
print("Midterm")
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)

#INPUT MIDTERM EXAM GRADE
print(" ")
MEX = float(input("Enter Midterm Exam grade: "))
#MIDTERM GRADE
MG = (PG*0.33) + (((MEX*0.5) + (MCS*0.5))*0.67)


#FINAL CLASS STANDING
print(" ")
print("Final")
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final CS is: ", FCS)

#INPUT FINAL EXAM GRADE
print(" ")
FEX = float(input("Enter Final Exam grade: "))
#FINAL GRADE
FG = (MG*0.33) + (((FEX*0.5) + (FCS*0.5))*0.67)

#COMPILE NAME OF STUDENT ALONG WITH GRADES FROM PRELIM, MIDTERM, AND FINALS
print(" ")
print("Student Name: ", str(Name))
print("Prelim Grade is: ", "%.2f" % PG)
print("Midterm Grade is: ", "%.2f" % MG)
print("Final Grade is: ", "%.2f" % FG)
print(" ")

#CONVERT FINAL GRADE TO TIP GRADE (ADD REMARKS IF YOU WANT)
if 100 >= FG >= 99:
  print("TIP Grade: 1.00")
  print("Remarks: Excellent")
elif 99 > FG >= 96:
  print("TIP Grade: 1.25")
  print("Remarks: Superior")
elif 96 > FG >= 93:
  print("TIP Grade: 1.50")
  print("Remarks: Meritorious")
elif 93 > FG >= 90:
  print("TIP Grade: 1.75")
  print("Remarks: Very Good")
elif 90 > FG >= 87:
  print("TIP Grade: 2.00")
  print("Remarks: Good")
elif 87 > FG >= 84:
  print("TIP Grade: 2.25")
  print("Remarks: Very Satisfactory")
elif 84 > FG >= 81:
  print("TIP Grade: 2.50")
  print("Remarks: Satisfactory")
elif 81 > FG >= 78:
  print("TIP Grade: 2.75")
  print("Remarks: Fair")
elif 78 > FG >= 75:
  print("TIP Grade: 3.00")
  print("Remarks: Passing")
else:
  print("TIP Grade: 5.00")
  print("Remarks: Failed")
print(" ")
# Out:
# Student 1
# Enter Student Name: John Doe
#
# Prelim
# Enter Hands-on Activity grade: 95
# Enter Prelim Quiz grade: 90
# Enter Prelim Assignment grade: 85
# Prelim CS is:  91.5
#
# Enter Prelim Exam grade: 75
#
# Midterm
# Enter Hands-on Activity grade: 85
# Enter Midterm Quiz grade: 70
# Enter Midterm Assignment grade: 84
# Midterm CS is:  80.3
#
# Enter Midterm Exam grade: 63
#
# Final
# Enter Hands-on Activity grade: 99
# Enter Final Quiz grade: 100
# Enter Final Assignment grade: 83
# Final CS is:  96.1
#
# Enter Final Exam grade: 74
#
# Student Name:  John Doe
# Prelim Grade is:  83.25
# Midterm Grade is:  75.48
# Final Grade is:  81.89
#
# TIP Grade: 2.50
# Remarks: Satisfactory
#
# Student 2
# Enter Student Name: Jane Doe
#
# Prelim
# Enter Hands-on Activity grade: 99
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 74
# Prelim CS is:  89.8
#
# Enter Prelim Exam grade: 73
#
# Midterm
# Enter Hands-on Activity grade: 72
# Enter Midterm Quiz grade: 71
# ...

# %% [markdown]
# **Conclusion**: In conclusion, literals and variables are a important part of code in Phyton. Implementing it will help you when dealing with constant numbers by in declaring them in a variables. You can use them in doing operations, identifying it's data type, apply in statements, etc.
