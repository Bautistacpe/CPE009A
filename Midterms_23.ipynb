# %% [markdown]
# <a href="https://colab.research.google.com/github/Bautistacpe/CPE009A/blob/main/Midterms_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 23
counter = 1
for i in range(1,6):
 number = "*" * counter
 if counter < 5:
   print(number)
   counter += 1
 else:
   print(number)
   counter -= 1
for i in range(6,10):
  number = "*" * counter
  counter -=1
  print(number)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
