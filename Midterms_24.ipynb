# %% [markdown]
# <a href="https://colab.research.google.com/github/Bautistacpe/CPE009A/blob/main/Midterms_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 24
counter = 2
def check_brackets(brackets):
  if brackets == ("[","{","(",")","}","]"):
   return False
  else:
     return True


print(check_brackets("({[]})"))
print(check_brackets("([)]"))
print(check_brackets("((()))"))
print(check_brackets("({)}"))
# Out:
# True
# True
# True
# True
