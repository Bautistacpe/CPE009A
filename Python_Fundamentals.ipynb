# %% [markdown]
# <a href="https://colab.research.google.com/github/Bautistacpe/CPE009A/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 5>2:
 print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Variable Naming Conventions

# %%
myvar = "John"
myVar = "John"
print(myvar)
# Out:
# John

# %% [markdown]
# Python Variable

# %%
x = 1
a, b = 0, -1
a, b, c = 0, -1, 2

# %%
b = "Sally" #This is a type of string
print(b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b = "sally" #This is a type of string
b = int(4)
print(b)

b = float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() Function

# %%
x = 5
y = "John"
z = "A"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# "Double quotes" or "Single quotes'

# %%
y = "John"
z = 'John'
print(y)
print(z)
# Out:
# John
# John

# %% [markdown]
# Case Sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(a)
# Out:
# 4

# %% [markdown]
# Multiple Variables

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variables

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x = "enjoying"
print("Python programming is " + x)

x = "Python is "
y = "enjoying"
z = x + y
print(z)
# Out:
# Python programming is enjoying
# Python is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
x = 5
y = 3
print (x + y)

a = 5
b = 3
sum = a+b
sum
# Out:
# 8
# 8

# %%
x = 5
y = 3
print (x - y)

a = 5
b = 3
difference = a-b
difference
# Out:
# 2
# 2

# %%
x = 5
y = 3
print (x * y)

a = 5
b = 3
product = a*b
product
# Out:
# 15
# 15

# %%
x = 5
y = 3
print (x / y)

a = 5
b = 3
quotient = a/b
# Out:
# 1.6666666666666667

# %%
x = 5
y = 3
print (x % y)

a = 5
b = 3
remainder = a%b
# Out:
# 2

# %%
x = 5
y = 3
print (x ** y)

a = 5
b = 3
sum = a**b
# Out:
# 125

# %%
x = 5
y = 3
print (x // y)

a = 5
b = 3
quotient2 = a//b
# Out:
# 1

# %% [markdown]
# Assignment Operators

# %%
s = 5
print(s)
# Out:
# 5

# %%
s = 1
s+=3
print(s)
# Out:
# 4

# %%
s = 1
s -= 3
print(s)
# Out:
# -2

# %%
s = 1
s /= 3
print(s)
# Out:
# 0.3333333333333333

# %%
s = 1
s %= 3
print(s)
# Out:
# 1

# %%
s = 1
s //= 3
print(s)
# Out:
# 0

# %%
s = 1
s **= 3
print(s)
# Out:
# 1

# %%
s = 1
s &= 3
print(s)
# Out:
# 1

# %%
s = 1
s |= 3
print(s)
# Out:
# 3

# %%
s = 1
s ^= 3
print(s)
# Out:
# 2

# %%
s = 1
s >>= 3
print(s)
# Out:
# 0

# %%
s = 1
s <<= 3
print(s)
# Out:
# 8

# %% [markdown]
# Comparison Operators

# %%
t = 1
u = 2
t == u
# Out:
# False

# %%
t = 1
u = 2
t != u
# Out:
# True

# %%
t = 1
u = 2
t > u
# Out:
# False

# %%
t = 1
u = 2
t < u
# Out:
# True

# %%
t = 1
u = 2
t >= u
# Out:
# False

# %%
t = 1
u = 2
t <= u
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
t < 5 and u < 10
# Out:
# True

# %%
t < 5 or u < 10
# Out:
# True

# %%
not(t < 5 and u < 10)
# Out:
# False

# %% [markdown]
# Identity Operators

# %%
t is u
# Out:
# False

# %%
t is not u
# Out:
# True

# %% [markdown]
# Bitwise Operators

# %%
v = 2
v << 1
# Out:
# 4

# %%
v = 2
v << 2
# Out:
# 8

# %%
1&2
# Out:
# 0

# %%
15&15
# Out:
# 15
